# %%
for n_past_values in [20,50,100,150]:
    n_future_values=20
    input_shape=(n_past_values,1)

    X_train_dir, y_train_dir,X_val_dir,y_val_dir,X_test_dir,y_test_dir = prepare_direct_lstm_data(data,n_past_values,n_future_values)
    dir_model = build_direct_lstm_model_simple(input_shape=input_shape, output_steps=n_future_values,lstm_units=64)
    dir_model.summary()
    dir_history = train_and_save_model(dir_model,X_train=X_train_dir, y_train=y_train_dir, X_val=X_val_dir, y_val=y_val_dir,name=f'{n_past_values}_simple_dir.keras',epochs=50)
    print(f"n_past_vals={n_past_values}")
    plot_training_history(dir_history[1])
    dir_pred=dir_model.predict(X_test_dir)
    er.evaluate_n_values(y_test_dir[:,-1],dir_pred[:,-1],n=20)
    er.evaluate_full_sequence(y_test_dir,dir_pred,2)
# Out:
# Model: "Direct_LSTM_Model_simple"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 20, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_layer (LSTM)               │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 20)             │         1,300 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,196 (71.08 KB)
#  Trainable params: 18,196 (71.08 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 509/513 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0379 - mae: 0.1026 - mse: 0.0379
# ...
